# %%
import pandas as pd
from Data_project import generar_datos_financieros

"""
Finzen: Análisis y visualización de datos financieros.
"""
# Datos de prueba
# Generar el DataFrame
datos_financieros = generar_datos_financieros()
df_financiero = pd.DataFrame(datos_financieros)

# Mostrar las primeras filas del DataFrame
print("DataFrame para Análisis Financiero:")
print(df_financiero.head(10))
print(f"\nDimensiones del DataFrame: {df_financiero.shape}")

# Mostrar las columnas del DataFrame
print(f"\nColumnas del DataFrame: {df_financiero.columns.tolist()}")

# Mostrar información del DataFrame
print("\nInformación del DataFrame:")
print(df_financiero.info())
# Out:
# DataFrame para Análisis Financiero:
#             nombre  edad situacion_laboral cuenta_con_ingresos_mensuales  \
# 0       Ana García    20      Emprendiendo                            si
# 1     Carlos López    28        Trabajando                            si
# 2  María Rodríguez    27        Estudiando                            si
# 3    Juan Martínez    29       Desempleado                            no
# 4  Laura Hernández    21        Estudiando                            no
# 5      Diego Pérez    20        Trabajando                            no
# 6   Sofía González    28       Desempleado                            no
# 7   Miguel Sánchez    21        Trabajando                            si
# 8       Elena Díaz    18        Estudiando                            no
# 9    David Ramírez    21       Desempleado                            no
#
#    ingresos                                   ingresos_detalle  \
# ...
